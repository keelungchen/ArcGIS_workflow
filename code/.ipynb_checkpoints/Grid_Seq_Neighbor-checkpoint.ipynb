# %%
import arcpy

# 取得目前開啟的 ArcGIS Pro 專案
aprx = arcpy.mp.ArcGISProject("CURRENT")
gdb = aprx.defaultGeodatabase 

aprx.defaultGeodatabase = gdb
arcpy.env.workspace = gdb

print("專案路徑：", aprx.filePath)              # .aprx 檔案完整路徑
print("預設 gdb：", aprx.defaultGeodatabase)   # 預設的 geodatabase
print("專案資料夾：", aprx.homeFolder)         # 專案所在的資料夾 (home folder)

# 取得目前活動的 Map (通常就是你 ArcGIS Pro 視窗左邊的那個)
m = aprx.activeMap

print("目前 Map 名稱:", m.name)

sr = m.spatialReference
print("圖層空間參考:", sr.name, sr.factoryCode)
# Out:
# 專案路徑： D:\ArcGIS\Morpho_Spatial_Demography\Morpho_Spatial_Demography.aprx
# 預設 gdb： D:\ArcGIS\Morpho_Spatial_Demography\MSD_Taiwan.gdb
# 專案資料夾： D:\ArcGIS\Morpho_Spatial_Demography
# 目前 Map 名稱: Taiwan
# 圖層空間參考: TWD_1997_TM_Taiwan 3826

# %%
###輸出plot中的小網格

import arcpy
import math
import os

arcpy.env.overwriteOutput = True  # 同名覆蓋
arcpy.env.addOutputsToMap = True  # 自動加到地圖

# ====== 參數 ======
in_fc    = "OL_P1_plot_6m"   # 輸入 Polygon (圖層或要素類別)
side_len = 0.04                            # 每格邊長 (公尺)
out_fc   = "OL_P1_grid_4cm_2209" # 輸出 (可用只寫檔名 + 設定 arcpy.env.workspace)

scratch  = arcpy.env.scratchGDB             # 暫存資料放這

# 暫存路徑
fishnet_fc  = os.path.join(scratch, "fishnet_tmp")
clipped_fc  = os.path.join(scratch, "grid_clip_tmp")

# 刪除舊暫存
for tmp in [fishnet_fc, clipped_fc]:
    if arcpy.Exists(tmp):
        arcpy.management.Delete(tmp)

# 1) 取得範圍
ext = arcpy.Describe(in_fc).extent
origin_coord = f"{ext.XMin} {ext.YMin}"
y_axis_coord = f"{ext.XMin} {ext.YMin + 1}"
opp_corner   = f"{ext.XMax} {ext.YMax}"

# 2) 建立 fishnet
arcpy.management.CreateFishnet(
    out_feature_class=fishnet_fc,
    origin_coord=origin_coord,
    y_axis_coord=y_axis_coord,
    cell_width=side_len,
    cell_height=side_len,
    number_rows=None,
    number_columns=None,
    corner_coord=opp_corner,
    labels="NO_LABELS",
    template=in_fc,
    geometry_type="POLYGON"
)

# 3) Clip 到原 Polygon
arcpy.analysis.Clip(fishnet_fc, in_fc, clipped_fc)

# 4) 複製到最終輸出
arcpy.management.CopyFeatures(clipped_fc, out_fc)
print("完成！輸出：", out_fc)

# 5) 清理暫存
for tmp in [fishnet_fc, clipped_fc]:
    if arcpy.Exists(tmp):
        arcpy.management.Delete(tmp)

# 6) 如果 ArcGIS 已經把暫存圖層加到地圖，從 activeMap 移掉它們
aprx = arcpy.mp.ArcGISProject("CURRENT")
m = aprx.activeMap
for name in ["fishnet_tmp", "grid_clip_tmp"]:
    for lyr in m.listLayers(name):
        m.removeLayer(lyr)
# Out:
# 完成！輸出： OL_P1_grid_4cm_2209

# %%
#網格編號

import arcpy
import statistics

fc = r"OL_P1_grid_4cm_2209"
seq_field = "SeqID"

if seq_field not in [f.name for f in arcpy.ListFields(fc)]:
    arcpy.AddField_management(fc, seq_field, "LONG")

cells = []
with arcpy.da.SearchCursor(fc, ["OID@", "SHAPE@XY"]) as cur:
    for oid, (x, y) in cur:
        cells.append((oid, x, y))

if not cells:
    raise ValueError("未讀取到任何幾何。")

ys = sorted([y for _, _, y in cells])
dy = [abs(ys[i+1] - ys[i]) for i in range(len(ys)-1) if abs(ys[i+1] - ys[i]) > 0]

# ✅ 容錯：如果無法估出row_spacing就給一個估計值
if len(dy) > 0:
    row_spacing = statistics.median(dy)
else:
    # 自動估算網格間距（取y範圍/假設10列）
    row_spacing = (max(ys) - min(ys)) / 10.0

# 給安全容差
tol = max(row_spacing * 0.5, 0.001)   # 保證最小容差非0

# === 依 Y 分群 ===
cells.sort(key=lambda r: r[2], reverse=True)
rows = []
current_row = []
anchor_y = cells[0][2]

for rec in cells:
    oid, x, y = rec
    if abs(y - anchor_y) <= tol:
        current_row.append(rec)
    else:
        rows.append(current_row)
        current_row = [rec]
        anchor_y = y
rows.append(current_row)

print(f"偵測到 {len(rows)} 列，每列約 {len(rows[0]) if rows else 0} 格。")

# === 每列左到右排序並編號 ===
seq = 1
oid_to_seq = {}
for row in rows:
    row_sorted = sorted(row, key=lambda r: r[1])
    for oid, _, _ in row_sorted:
        oid_to_seq[oid] = seq
        seq += 1

with arcpy.da.UpdateCursor(fc, ["OID@", seq_field]) as cur:
    for oid, _ in cur:
        cur.updateRow((oid, oid_to_seq[oid]))

print(f"✅ 已完成 SeqID 編號，共 {seq-1} 個格子。")
# Out:
# 偵測到 150 列，每列約 150 格。
# ✅ 已完成 SeqID 編號，共 22500 個格子。

# %%
import arcpy

# 設定環境：允許覆蓋同名檔案
arcpy.env.overwriteOutput = True

# ==========================================
# 1. 參數設定區
# ==========================================
# 請修改為您的實際檔案路徑
grid_layer = r"D:\ArcGIS\Morpho_Spatial_Demography\MSD_Taiwan.gdb\OL_P1_grid_4cm_2209"

# 暫存鄰居表 (存於記憶體，程式結束自動消失)
neighbors_table = r"memory\PolyNeigh_Temp" 

# 網格唯一識別碼欄位 (必須存在於 grid_layer 中)
id_field = "SeqID"

# 容許誤差 (判斷座標是否在同一直線上)
tol = 1e-6

# ==========================================
# 2. 自動建立並計算 x, y 座標
# ==========================================
print("正在計算網格中心點 X, Y 座標...")

# 檢查欄位是否存在，不存在則建立
current_fields = [f.name for f in arcpy.ListFields(grid_layer)]
if "x" not in current_fields:
    arcpy.AddField_management(grid_layer, "x", "DOUBLE")
if "y" not in current_fields:
    arcpy.AddField_management(grid_layer, "y", "DOUBLE")

# 計算幾何屬性 (中心點座標)
arcpy.management.CalculateGeometryAttributes(
    in_features=grid_layer,
    geometry_property=[["x", "CENTROID_X"], ["y", "CENTROID_Y"]]
)

# ==========================================
# 3. 執行 Polygon Neighbors (修正參數名稱為 in_fields)
# ==========================================
print("正在執行 Polygon Neighbors 分析...")

# 
# 在 Python 中，界面上的 "Report by fields" 對應的參數名稱是 in_fields
arcpy.analysis.PolygonNeighbors(
    in_features=grid_layer,
    out_table=neighbors_table,
    in_fields=[id_field] 
)

# ==========================================
# 4. 判斷方位並更新回圖層
# ==========================================
print("正在計算四方鄰居關係...")

# 1. 讀取網格座標字典 {SeqID: (x, y)}
grid_dict = {}
with arcpy.da.SearchCursor(grid_layer, [id_field, "x", "y"]) as cursor:
    for seqid, x, y in cursor:
        if seqid is not None:
            grid_dict[seqid] = (x, y)

# 2. 初始化結果容器
neighbors_result = {
    seqid: {"up_side": None, "down_side": None, "left_side": None, "right_side": None} 
    for seqid in grid_dict.keys()
}

# 3. 讀取鄰居表 (欄位名稱會自動加上 src_ 和 nbr_ 前綴)
src_field = f"src_{id_field}"
nbr_field = f"nbr_{id_field}"

with arcpy.da.SearchCursor(neighbors_table, [src_field, nbr_field]) as cursor:
    for src_id, nbr_id in cursor:
        if src_id in grid_dict and nbr_id in grid_dict:
            src_x, src_y = grid_dict[src_id]
            nbr_x, nbr_y = grid_dict[nbr_id]
            
            dx = nbr_x - src_x
            dy = nbr_y - src_y

            # 判斷左右 (Y 軸差異極小)
            if abs(dy) < tol:
                if dx > tol:
                    neighbors_result[src_id]["right_side"] = nbr_id
                elif dx < -tol:
                    neighbors_result[src_id]["left_side"] = nbr_id
            
            # 判斷上下 (X 軸差異極小)
            elif abs(dx) < tol:
                if dy > tol:
                    neighbors_result[src_id]["up_side"] = nbr_id
                elif dy < -tol:
                    neighbors_result[src_id]["down_side"] = nbr_id

# 4. 確保欄位存在
target_fields = ["up_side", "down_side", "left_side", "right_side"]
existing_fields = [f.name for f in arcpy.ListFields(grid_layer)]
for f in target_fields:
    if f not in existing_fields:
        # 注意：如果你的 SeqID 是長整數，用 LONG；如果是文字，請改為 "TEXT"
        arcpy.AddField_management(grid_layer, f, "LONG") 

# 5. 更新回屬性表
print("正在寫入鄰居資訊...")
update_cols = [id_field] + target_fields
with arcpy.da.UpdateCursor(grid_layer, update_cols) as cursor:
    for row in cursor:
        seqid = row[0]
        if seqid in neighbors_result:
            res = neighbors_result[seqid]
            row[1] = res["up_side"]
            row[2] = res["down_side"]
            row[3] = res["left_side"]
            row[4] = res["right_side"]
            cursor.updateRow(row)

print("✅ 處理完成：座標計算與四方鄰居更新完畢。")
# Out:
# 正在計算網格中心點 X, Y 座標...
# 正在執行 Polygon Neighbors 分析...
# 正在計算四方鄰居關係...
# 正在寫入鄰居資訊...
# ✅ 處理完成：座標計算與四方鄰居更新完畢。

# %%
import arcpy

# ==============================================================================
# 🚀 第一階段：精確空間連接 (Spatial Join) 與 自動清理
# ==============================================================================

# 1. 參數設定
fc_grid = r"D:\ArcGIS\Morpho_Spatial_Demography\MSD_Taiwan.gdb\OL_P1_grid_4cm"
fc_coral = r"D:\ArcGIS\Morpho_Spatial_Demography\MSD_Taiwan.gdb\OL_P1_2204_coral_Simplify" 
temp_sj_name = "smart_sj"
temp_sj = r"memory" + "\\" + temp_sj_name

# --- 🆕 新增：檢查來源圖層欄位是否存在 ---
coral_fields = [f.name for f in arcpy.ListFields(fc_coral)]
has_fate = "Fate" in coral_fields
has_fu = "Fu_group" in coral_fields

print("正在執行精確 Spatial Join 並配置 FieldMappings...")

# 1-1. 確保 fc_grid 欄位格式
# 🆕 加入 Colony_Fate 與 Fu_group 欄位建立邏輯
fields_to_add = [("Colony_ID", "LONG"), ("Form", "TEXT")]
if has_fate: fields_to_add.append(("Colony_Fate", "TEXT"))
if has_fu: fields_to_add.append(("Fu_group", "TEXT"))

for f, f_type in fields_to_add:
    if f not in [field.name for field in arcpy.ListFields(fc_grid)]:
        arcpy.AddField_management(fc_grid, f, f_type, field_length=50 if f_type=="TEXT" else None)

# 1-2. 建立 FieldMappings
field_mappings = arcpy.FieldMappings()
fm_seq = arcpy.FieldMap()
fm_seq.addInputField(fc_grid, "SeqID")
field_mappings.addFieldMap(fm_seq)

# 將 ID 映射到 Colony_ID
fm_colony = arcpy.FieldMap()
fm_colony.addInputField(fc_coral, "ID")
new_field = fm_colony.outputField
new_field.name = "Colony_ID"
fm_colony.outputField = new_field
field_mappings.addFieldMap(fm_colony)

# 加入 Form
fm_form = arcpy.FieldMap()
fm_form.addInputField(fc_coral, "Form")
field_mappings.addFieldMap(fm_form)

# 🆕 加入 Fate 並改名為 Colony_Fate (Field Mapping 處理)
if has_fate:
    fm_fate = arcpy.FieldMap()
    fm_fate.addInputField(fc_coral, "Fate")
    new_fate_field = fm_fate.outputField
    new_fate_field.name = "Colony_Fate"
    fm_fate.outputField = new_fate_field
    field_mappings.addFieldMap(fm_fate)

# 🆕 加入 Fu_group
if has_fu:
    fm_fu = arcpy.FieldMap()
    fm_fu.addInputField(fc_coral, "Fu_group")
    field_mappings.addFieldMap(fm_fu)

# 1-3. 執行 Spatial Join 至記憶體
arcpy.analysis.SpatialJoin(
    target_features=fc_grid,
    join_features=fc_coral,
    out_feature_class=temp_sj,
    join_operation="JOIN_ONE_TO_ONE",
    join_type="KEEP_ALL",
    field_mapping=field_mappings,
    match_option="HAVE_THEIR_CENTER_IN"
)

# 1-4. 透過字典回寫資料
# 🆕 動態構建回寫欄位清單
sj_fields = ["SeqID", "Colony_ID", "Form"]
if has_fate: sj_fields.append("Colony_Fate")
if has_fu: sj_fields.append("Fu_group")

# 讀取資料
sj_data = {}
with arcpy.da.SearchCursor(temp_sj, sj_fields) as sCursor:
    for row in sCursor:
        # row[0] 是 SeqID, 其餘是資料
        sj_data[row[0]] = row[1:]

# 回寫至 fc_grid
with arcpy.da.UpdateCursor(fc_grid, sj_fields) as uCursor:
    for row in uCursor:
        sid = row[0]
        if sid in sj_data:
            data = sj_data[sid]
            # row[1:] 對應 data[0:]
            for i in range(len(data)):
                row[i+1] = data[i]
            uCursor.updateRow(row)

# --- 🔥 從 Contents 面板移除圖層 並 刪除記憶體資料 🔥 ---
print("正在執行環境清理 (移除面板圖層與記憶體資料)...")

try:
    aprx = arcpy.mp.ArcGISProject("CURRENT")
    for m in aprx.listMaps():
        for lyr in m.listLayers(temp_sj_name):
            m.removeLayer(lyr)
            print(f"  - 已從地圖 '{m.name}' 的內容面板移除圖層: {temp_sj_name}")
except Exception as e:
    print(f"  - 略過介面清理步驟 (可能非於 Pro 介面執行): {e}")

if arcpy.Exists(temp_sj):
    arcpy.management.Delete(temp_sj)

print("✅ 第一階段：資料寫入與環境清理完成。")

# ==============================================================================
# 🚀 第二階段：原始鄰居計算邏輯 (完全保留原本邏輯)
# ==============================================================================

print("開始執行第二階段：鄰居分析...")

# === 2. 確保輸出欄位存在 ===
for f in ["up_type", "down_type", "left_type", "right_type", "Self_count", "Ncoral_count", "Comp_count"]:
    field_names = [field.name for field in arcpy.ListFields(fc_grid)]
    if f not in field_names:
        if f in ("Self_count", "Ncoral_count", "Comp_count"):
            arcpy.AddField_management(fc_grid, f, "SHORT")
        else:
            arcpy.AddField_management(fc_grid, f, "TEXT", field_length=20)

# === 3. 建立 SeqID -> Colony_ID, Form 對照 ===
colony_dict = {}
form_dict = {}

with arcpy.da.SearchCursor(fc_grid, ["SeqID", "Colony_ID", "Form"]) as sCur:
    for seqid, colony, form in sCur:
        colony_dict[seqid] = colony
        form_dict[seqid] = form

# === 4. Form 代碼對照字典 ===
form_code_map = {
    1: "br", 2: "cb", 3: "di", 4: "co", 5: "ta", 6: "ma",
    7: "en", 8: "fr", 9: "fo", 10: "bu", 11: "su"
}
form_text_set = set(form_code_map.values())

# === 5. 定義比對函式 ===
def compare_colony(src_colony, nbr_colony, nbr_form):
    if nbr_colony in (None, "", " "):
        return "Ncoral"
    if src_colony == nbr_colony:
        return "Self"
    if nbr_form in (None, "", " "):
        return "Unknown"
    try:
        nbr_form_code = int(nbr_form)
        return form_code_map.get(nbr_form_code, str(nbr_form))
    except Exception:
        return str(nbr_form)

# === 6. 更新四個方向與統計欄位 ===
fields = [
    "SeqID", "Colony_ID", "Form",
    "up_side", "down_side", "left_side", "right_side",
    "up_type", "down_type", "left_type", "right_type",
    "Self_count", "Ncoral_count", "Comp_count"
]

with arcpy.da.UpdateCursor(fc_grid, fields) as uCur:
    for row in uCur:
        src_seq, src_colony, src_form = row[0], row[1], row[2]
        up_seq, down_seq, left_seq, right_seq = row[3], row[4], row[5], row[6]

        up_result = down_result = left_result = right_result = "Unknown"

        if up_seq in colony_dict:
            up_result = compare_colony(src_colony, colony_dict[up_seq], form_dict.get(up_seq))
        if down_seq in colony_dict:
            down_result = compare_colony(src_colony, colony_dict[down_seq], form_dict.get(down_seq))
        if left_seq in colony_dict:
            left_result = compare_colony(src_colony, colony_dict[left_seq], form_dict.get(left_seq))
        if right_seq in colony_dict:
            right_result = compare_colony(src_colony, colony_dict[right_seq], form_dict.get(right_seq))

        row[7], row[8], row[9], row[10] = up_result, down_result, left_result, right_result
        neighbor_types = [up_result, down_result, left_result, right_result]

        row[11] = sum(1 for v in neighbor_types if v == "Self")
        row[12] = sum(1 for v in neighbor_types if v == "Ncoral")
        row[13] = sum(1 for v in neighbor_types if v in form_text_set)

        uCur.updateRow(row)

# === 🆕 最終欄位狀態回報 ===
print("-" * 30)
print("【欄位處理回報】")
if has_fate:
    print("✅ 成功處理 Fate 欄位 (已更名為 Colony_Fate)")
else:
    print("⚠️ 來源圖層缺少 Fate 欄位，已跳過。")

if has_fu:
    print("✅ 成功處理 Fu_group 欄位")
else:
    print("⚠️ 來源圖層缺少 Fu_group 欄位，已跳過。")
print("-" * 30)

print("✅ 全部程序已成功完成！")
# Out:
# 正在執行精確 Spatial Join 並配置 FieldMappings...
# 正在執行環境清理 (移除面板圖層與記憶體資料)...
#   - 已從地圖 'Taiwan' 的內容面板移除圖層: smart_sj
# ✅ 第一階段：資料寫入與環境清理完成。
# 開始執行第二階段：鄰居分析...
# ------------------------------
# 【欄位處理回報】
# ✅ 成功處理 Fate 欄位 (已更名為 Colony_Fate)
# ✅ 成功處理 Fu_group 欄位
# ------------------------------
# ✅ 全部程序已成功完成！

# %%
##計算網格平均高度

import arcpy
from arcpy import env
from arcpy.sa import *

# 檢查 Spatial Analyst 擴充模組授權
if arcpy.CheckExtension("Spatial") == "Available":
    arcpy.CheckOutExtension("Spatial")
else:
    raise Exception("需要 Spatial Analyst 授權才能執行 Zonal Statistics")

# 設置環境
env.overwriteOutput = True

############# 設定區 #######################
# 1. 原始網格資料
fc_grid = r"D:\ArcGIS\Morpho_Spatial_Demography\MSD_Taiwan.gdb\OL_P1_grid_4cm_2209"
# 2. 高度來源 (DEM 數值地形模型)
dem_raster = r"D:\SfM_coral_reefs_product\Southern_Taiwan\Outlet\OL_P1\OL_P1_2209_DEM_3826_2mm.tif" 
# 3. 識別碼欄位
id_field = "SeqID"
# 4. 臨時輸出的表格路徑
zonal_temp_table = "memory/zonal_stats_temp" 

#----------------------------------------------------------------
# 1. 執行 Zonal Statistics as Table 計算 Cell_Z_mean
#----------------------------------------------------------------
print("正在執行 Zonal Statistics 計算平均高度...")
# 注意：這裡使用 MEAN 作為統計類型，產出的欄位名稱預設會是 "MEAN"
ZonalStatisticsAsTable(fc_grid, id_field, dem_raster, zonal_temp_table, "DATA", "MEAN")

#----------------------------------------------------------------
# 2. 檢查並建立鄰居高度欄位 (如果不存在就建立)
#----------------------------------------------------------------
height_fields = ["Cell_Z_mean", "up_hight", "down_hight", "left_hight", "right_hight"]
existing_fields = [f.name for f in arcpy.ListFields(fc_grid)]
for field in height_fields:
    if field not in existing_fields:
        arcpy.AddField_management(fc_grid, field, "DOUBLE")

#----------------------------------------------------------------
# 3. 建立 SeqID -> Mean_Height 對應字典
#    從剛剛產出的臨時表 (zonal_temp_table) 中讀取資料
#----------------------------------------------------------------
depth_dict = {}
# Zonal Statistics 表格中，SeqID 是我們指定的，MEAN 是工具算出來的結果
with arcpy.da.SearchCursor(zonal_temp_table, [id_field, "MEAN"]) as sCur:
    for seqid, mean_val in sCur:
        if seqid is not None:
            try:
                depth_dict[int(seqid)] = mean_val
            except Exception:
                pass

print(f"字典建立完成，共計 {len(depth_dict)} 筆數據。")

#----------------------------------------------------------------
# 4. 使用 UpdateCursor 更新本機網格高度及鄰居高度值
#----------------------------------------------------------------
fields = [id_field, "up_side", "down_side", "left_side", "right_side",
          "up_hight", "down_hight", "left_hight", "right_hight", "Cell_Z_mean"]

def convert_to_int(val):
    try:
        if val is None or str(val).strip() == "":
            return None
        return int(val)
    except Exception:
        return None

with arcpy.da.UpdateCursor(fc_grid, fields) as uCur:
    for row in uCur:
        # A. 更新本網格的高度 (Cell_Z_mean)
        current_seq = convert_to_int(row[0])
        if current_seq in depth_dict:
            row[9] = depth_dict[current_seq]

        # B. 取得各方向鄰居的 SeqID
        up_side    = convert_to_int(row[1])
        down_side  = convert_to_int(row[2])
        left_side  = convert_to_int(row[3])
        right_side = convert_to_int(row[4])
        
        # C. 更新各方向高度值
        row[5] = depth_dict.get(up_side)    if up_side in depth_dict else None
        row[6] = depth_dict.get(down_side)  if down_side in depth_dict else None
        row[7] = depth_dict.get(left_side)  if left_side in depth_dict else None
        row[8] = depth_dict.get(right_side) if right_side in depth_dict else None
        
        uCur.updateRow(row)

# 釋放授權
arcpy.CheckInExtension("Spatial")
print("所有高度值（包含本網格與鄰居）已更新完成！")
# Out:
# 正在執行 Zonal Statistics 計算平均高度...
# 字典建立完成，共計 22500 筆數據。
# 所有高度值（包含本網格與鄰居）已更新完成！

# %%
##計算網格間寺方高度差

import arcpy

############# 計算網格四方鄰居的平均高度差 #######################
###### 需要先用 Zonal Statistics as Table 或其他方式計算 Cell_Z_mean ########

# 資料來源：請確認路徑正確
fc_grid = r"D:\ArcGIS\Morpho_Spatial_Demography\MSD_Taiwan.gdb\OL_P1_grid_4cm_2209"

#----------------------------------------------------------------
# 1. 檢查並建立「相鄰網格高度差」與「總平均高度差」欄位
#----------------------------------------------------------------
diff_fields = ["up_h_diff", "down_h_diff", "left_h_diff", "right_h_diff", "Total_h_diff"]
existing_fields = [f.name for f in arcpy.ListFields(fc_grid)]
for field in diff_fields:
    if field not in existing_fields:
        arcpy.AddField_management(fc_grid, field, "DOUBLE")

#----------------------------------------------------------------
# 2. 使用 UpdateCursor 根據 Cell_Z_mean 與鄰居高度計算高度差
#----------------------------------------------------------------
fields = [
    "SeqID",
    "Cell_Z_mean",
    "up_h_diff",
    "down_h_diff",
    "left_h_diff",
    "right_h_diff",
    "up_hight",
    "down_hight",
    "left_hight",
    "right_hight",
    "Total_h_diff"
]

with arcpy.da.UpdateCursor(fc_grid, fields) as uCur:
    for row in uCur:
        src_height = row[1]  # 本網格高度

        # 取得相鄰高度
        up_height    = row[6]
        down_height  = row[7]
        left_height  = row[8]
        right_height = row[9]

        # 計算高度差
        up_diff    = up_height - src_height    if (up_height is not None and src_height is not None) else None
        down_diff  = down_height - src_height  if (down_height is not None and src_height is not None) else None
        left_diff  = left_height - src_height  if (left_height is not None and src_height is not None) else None
        right_diff = right_height - src_height if (right_height is not None and src_height is not None) else None

        # 寫回各方向高度差
        row[2] = up_diff
        row[3] = down_diff
        row[4] = left_diff
        row[5] = right_diff

        # 計算四方向平均高度差（排除 None 值）
        diffs = [d for d in [up_diff, down_diff, left_diff, right_diff] if d is not None]
        row[10] = sum(diffs) / len(diffs) if len(diffs) > 0 else None

        uCur.updateRow(row)

print("✅ up_h_diff, down_h_diff, left_h_diff, right_h_diff, Total_h_diff 已更新完成！")
# Out:
# ✅ up_h_diff, down_h_diff, left_h_diff, right_h_diff, Total_h_diff 已更新完成！

# %%
import arcpy
import math

# 設定工作圖層，請確認圖層名稱或路徑正確
layer = r"D:\ArcGIS\Morpho_Spatial_Demography\MSD_Taiwan.gdb\OL_P1_grid_4cm_2209"

# 要更新的欄位清單
update_fields = ["Angle_West", "Angle_East", "ArcSunlight"]

# 若欄位已存在就刪除再重新建立，以便覆寫
for fld in update_fields:
    try:
        arcpy.DeleteField_management(layer, fld)
    except Exception:
        # 如果欄位不存在，就忽略錯誤
        pass
    arcpy.AddField_management(layer, fld, "DOUBLE")

# 每個網格的水平距離 (4 公分 = 0.04 m)
grid_size = 0.02        ################要記得改

# 使用 UpdateCursor 更新計算結果
with arcpy.da.UpdateCursor(layer, ["Cell_Z_mean", "left_hight", "right_hight",
                                   "Angle_West", "Angle_East", "ArcSunlight"]) as cursor:
    for row in cursor:
        depth     = row[0]  # 本網格的平均高度 Cell_Z_mean
        left_val  = row[1]  # 左側網格高度
        right_val = row[2]  # 右側網格高度
        
        # 若中心高度或左右任一側為空值，則將結果設為空值並更新
        if depth is None or left_val is None or right_val is None:
            row[3] = None
            row[4] = None
            row[5] = None
            cursor.updateRow(row)
            continue
        
        # 計算左側 (西側) 高度差及夾角
        diff_left = left_val - depth
        angle_west = math.degrees(math.atan(diff_left / grid_size))
        
        # 計算右側 (東側) 高度差及夾角
        diff_right = right_val - depth
        angle_east = math.degrees(math.atan(diff_right / grid_size))
        
        # 分別計算各側「逆角」：90° - 夾角
        inv_west = 90 - angle_west
        inv_east = 90 - angle_east
        
        # 日照弧為兩側逆角之和
        arc_sun = inv_west + inv_east

        # 更新欄位值
        row[3] = angle_west
        row[4] = angle_east
        row[5] = arc_sun
        
        cursor.updateRow(row)

print("夾角與日照弧計算完成（使用 Cell_Z_mean 欄位）！")
# Out:
# 夾角與日照弧計算完成（使用 Cell_Z_mean 欄位）！

# %%
import pandas as pd
import numpy as np
import arcpy
import os
from arcpy.sa import *

#==============================================================
# 🧭【參數設定區 — 只需修改這裡】
#==============================================================

fc_grid  = r"D:\ArcGIS\Morpho_Spatial_Demography\MSD_Taiwan.gdb\OL_P1_grid_4cm"
fc_coral = r"D:\ArcGIS\Morpho_Spatial_Demography\MSD_Taiwan.gdb\OL_P1_2204_coral_Simplify"
dem_raster = r"D:\ArcGIS\Morpho_Spatial_Demography\OL_P1_2204_DEM_3826_1mm.tif" 
out_csv  = r"D:\ArcGIS\Morpho_Spatial_Demography\data\OL_P1_grid_4cm_summary.csv"

cell_size_m = 0.04 
cell_area_m2 = cell_size_m ** 2

coral_forms = ["br","cb","di","co","ta","ma","en","fr","fo","bu","su"]
form_domain = {
    1:"br",2:"cb",3:"di",4:"co",5:"ta",6:"ma",
    7:"en",8:"fr",9:"fo",10:"bu",11:"su"
}

arcpy.env.overwriteOutput = True

#==============================================================
# 0. 【自動抓取 Fate 欄位的 Domain 對應表】
#==============================================================
print("正在讀取 Fate 欄位的 Domain 設定...")
fate_domain_map = {}
desc_coral = arcpy.Describe(fc_coral)
workspace = desc_coral.path
while workspace and not workspace.endswith(".gdb"):
    workspace = os.path.dirname(workspace)

if workspace:
    domains = arcpy.da.ListDomains(workspace)
    target_domain_name = next((f.domain for f in desc_coral.fields if f.name == "Fate"), "")
    if target_domain_name:
        for domain in domains:
            if domain.name == target_domain_name:
                fate_domain_map = domain.codedValues
                break



#==============================================================
# 0-1. 【計算 Polygon 的 Z Mean 與 STD 並更新回 fc_coral】
#==============================================================
print("正在計算珊瑚多邊形的 Zonal Statistics...")
if arcpy.CheckExtension("Spatial") == "Available":
    arcpy.CheckOutExtension("Spatial")
else:
    raise Exception("❌ 需要 Spatial Analyst 授權")

zonal_temp = "memory/zonal_stats"
ZonalStatisticsAsTable(fc_coral, "ID", dem_raster, zonal_temp, "DATA", "ALL")



target_fields = ["Colony_Z_Mean", "Colony_Z_STD"]
existing_fc_fields = [f.name for f in arcpy.ListFields(fc_coral)]
for f in target_fields:
    if f not in existing_fc_fields:
        arcpy.AddField_management(fc_coral, f, "DOUBLE")

stats_dict = {}
with arcpy.da.SearchCursor(zonal_temp, ["ID", "MEAN", "STD"]) as sc:
    for row in sc:
        stats_dict[row[0]] = (row[1], row[2])

with arcpy.da.UpdateCursor(fc_coral, ["ID", "Colony_Z_Mean", "Colony_Z_STD"]) as uc:
    for row in uc:
        if row[0] in stats_dict:
            row[1], row[2] = stats_dict[row[0]]
            uc.updateRow(row)

arcpy.CheckInExtension("Spatial")
print("✅ Zonal Statistics 計算並更新完成")

#==============================================================
# 1. 從 GIS 圖層讀取 fc_grid
#==============================================================
fields_grid = [
    "Colony_ID","Cell_Z_Mean","ArcSunlight",
    "up_type","down_type","left_type","right_type",
    "up_h_diff","down_h_diff","left_h_diff","right_h_diff"
]

records = []
with arcpy.da.SearchCursor(fc_grid, fields_grid) as cursor:
    for row in cursor:
        records.append(list(row))

df = pd.DataFrame(records, columns=fields_grid)
df = df.replace({None: np.nan})

#==============================================================
# 2. 處理類別與次數計算
#==============================================================
type_cols = ["up_type","down_type","left_type","right_type"]
for col in type_cols:
    df[col] = df[col].astype(str).str.lower().str.strip()

base_types = ["Self","Ncoral","Coral","Unknow"]
for col in base_types + coral_forms:
    df[f"{col}_count"] = 0

def count_type_detailed(row, cols):
    counts = {k: 0 for k in base_types + coral_forms}
    for c in cols:
        val = row[c]
        if val == "self": counts["Self"] += 1
        elif val == "ncoral": counts["Ncoral"] += 1
        elif val in coral_forms:
            counts[val] += 1
            counts["Coral"] += 1
        elif val == "coral": counts["Coral"] += 1
        else: counts["Unknow"] += 1
    return counts

for i, r in df.iterrows():
    c = count_type_detailed(r, type_cols)
    for k, v in c.items():
        df.at[i, f"{k}_count"] = v

#==============================================================
# 4 & 5. 建立 Pair 資料表與計算 MarRH (包含定義輔助函式)
#==============================================================
rows = []
for _, row in df.iterrows():
    cid = row["Colony_ID"]
    for side in ["up", "down", "left", "right"]:
        rows.append({
            "Colony_ID": cid, 
            "PairType": row[f"{side}_type"], 
            "PairHight": row[f"{side}_h_diff"]
        })

df_pairs = pd.DataFrame(rows)
df_pairs["PairHight"] = pd.to_numeric(df_pairs["PairHight"], errors="coerce")

def mean_if_valid(sub, cond):
    x = sub.loc[cond & pd.notnull(sub["PairHight"]), "PairHight"]
    return x.mean() if len(x) else np.nan

# --- 定義 MarRH 計算所需的導師函式 ---
def get_T(sub):  return mean_if_valid(sub, sub["PairType"] != "self")
def get_NC(sub): return mean_if_valid(sub, sub["PairType"] == "ncoral")
def get_C(sub):  return mean_if_valid(sub, sub["PairType"].isin(["coral"] + coral_forms))

# 使用 include_groups=False 消除 FutureWarning
df_marRH = (
    df_pairs.groupby("Colony_ID")
    .apply(lambda g: pd.Series({
        "T_MarRH": get_T(g),
        "NC_MarRH": get_NC(g),
        "C_MarRH": get_C(g)
    }), include_groups=False)
    .reset_index()
)



#==============================================================
# 6 & 7. 匯總統計、面積與 Edge 計算
#==============================================================
group_cols = ["Self_count","Ncoral_count","Coral_count","Unknow_count"] + [f"{f}_count" for f in coral_forms]
gdf = df.groupby("Colony_ID", as_index=False)[group_cols].sum()

gdf["Total_cells"] = (gdf["Self_count"] + gdf["Ncoral_count"] + gdf["Coral_count"] + gdf["Unknow_count"]) / 4.0
gdf["Raster_Area"] = gdf["Total_cells"] * cell_area_m2
gdf["Raster_Perimeter"] = (gdf["Ncoral_count"] + gdf["Coral_count"] + gdf["Unknow_count"]) * cell_size_m

def is_edge(row):
    return any(row[c] != "self" for c in type_cols if pd.notna(row[c]))
df["is_edge"] = df.apply(is_edge, axis=1)

edge_stats = df[df["is_edge"]].groupby("Colony_ID").agg(
    Edge_CellZ_mean=("Cell_Z_Mean","mean"), Edge_CellZ_std=("Cell_Z_Mean","std"),
    Edge_Sun_mean=("ArcSunlight","mean"), Edge_Sun_std=("ArcSunlight","std")
).reset_index()

colony_stats = df.groupby("Colony_ID").agg(
    Colony_CellZ_mean=("Cell_Z_Mean","mean"), Colony_CellZ_std=("Cell_Z_Mean","std"),
    Colony_Sun_mean=("ArcSunlight","mean"), Colony_Sun_std=("ArcSunlight","std")
).reset_index()

for d in [edge_stats, colony_stats]:
    for c in d.columns:
        if c != "Colony_ID": d[c] = d[c].round(3)

gdf = gdf.merge(edge_stats, on="Colony_ID", how="left").merge(colony_stats, on="Colony_ID", how="left")
merge_df = pd.merge(gdf, df_marRH, on="Colony_ID", how="left")

#==============================================================
# 9. 從珊瑚圖層匯入真實資料 (含 Fate & Form 轉換)
#==============================================================
arr_fields = ["ID","Form","Fate","Shape_Area","Shape_Length","Colony_Z_Mean","Colony_Z_STD"]
arr = arcpy.da.TableToNumPyArray(fc_coral, arr_fields, skip_nulls=False, null_value=np.nan)
df_coral = pd.DataFrame(arr)

def clean_id(v):
    if pd.isna(v): return ""
    s = str(v).strip()
    if s.endswith(".0"): s = s[:-2]
    return s

df_coral["Colony_ID"] = df_coral["ID"].apply(clean_id)
merge_df["Colony_ID"] = merge_df["Colony_ID"].apply(clean_id)

def translate_form(v):
    try:
        code = int(v)
        return form_domain.get(code, str(v))
    except:
        return str(v).strip().lower() if pd.notna(v) else ""

def translate_fate(v):
    if pd.isna(v): return ""
    return fate_domain_map.get(v, str(v))

df_coral["Form"] = df_coral["Form"].apply(translate_form)
df_coral["Colony_Fate"] = df_coral["Fate"].apply(translate_fate)

final_df = merge_df.merge(
    df_coral[["Colony_ID","Form","Colony_Fate","Shape_Area","Shape_Length","Colony_Z_Mean","Colony_Z_STD"]],
    on="Colony_ID", how="left"
)

#==============================================================
# 10. 輸出結果
#==============================================================
final_df.to_csv(out_csv, index=False, encoding="utf-8-sig")

print("---")
print(f"✅ 任務完成：{os.path.basename(out_csv)}")
print(f"📊 總筆數：{len(final_df)}")
print(f"💡 包含新欄位：Colony_Fate, Colony_Z_Mean, Colony_Z_STD")
# Out:
# 正在讀取 Fate 欄位的 Domain 設定...
# 正在計算珊瑚多邊形的 Zonal Statistics...
# ✅ Zonal Statistics 計算並更新完成
# ---
# ✅ 任務完成：OL_P1_grid_4cm_summary.csv
# 📊 總筆數：1086
# 💡 包含新欄位：Colony_Fate, Colony_Z_Mean, Colony_Z_STD

# %%
import arcpy
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# ==========================================
# 1. 參數設定區
# ==========================================
input_layer = r"OL_P1_2204_coral_Simplify" 
input_csv = r"D:\ArcGIS\Morpho_Spatial_Demography\data\OL_P1_grid_4cm_summary.csv"
output_csv = r"D:\ArcGIS\Morpho_Spatial_Demography\data\OL_P1_2204_grid_colony_results.csv"

csv_id_field = "Colony_ID"
layer_id_field = "ID"
form_field = "Form"
fate_col_field = "Colony_Fate" # 原有的 Colony_Fate

# 面積門檻 (直徑 5cm)
THRESHOLD_5CM_AREA = 3.14159265 * (0.025**2) 

# Form 代碼轉換表
form_domain = {
    "1":"br", "2":"cb", "3":"di", "4":"co", "5":"ta", "6":"ma",
    "7":"en", "8":"fr", "9":"fo", "10":"bu", "11":"su", "12":"NAN"
}

# 🆕 Fate 代碼轉換表
fate_domain = {
    "1":"D", "2":"G", "3":"S", "4":"Fi", "5":"GorS", "6":"Fu", "7":"Other"
}

target_fields = [
    "Shape_Length", "Shape_Area", "Shape_Area_T2", "Shape_Length_T2", 
    "Growth_Rate_Yan", "Circ_T1", "Circ_T2", "Circ_Rate_Yan", 
    "PAratio_T1", "PAratio_T2", "PAratio_Rate_Yan", 
    "Growth_Rate_Year", "Circ_Rate_Year", "PAratio_Year", "Fate"
]

# ==========================================
# 2. 提取圖層資料與動態命名
# ==========================================
arcpy.AddMessage("Loading layer data and handling fields...")
csv_df = pd.read_csv(input_csv)
csv_cols = set(csv_df.columns)

existing_fields = [f.name for f in arcpy.ListFields(input_layer)]
fetch_list = [layer_id_field]
for f in target_fields + [form_field, fate_col_field]:
    if f in existing_fields:
        fetch_list.append(f)

layer_rows = []
with arcpy.da.SearchCursor(input_layer, fetch_list) as cursor:
    for row in cursor:
        layer_rows.append(row)
layer_df = pd.DataFrame(layer_rows, columns=fetch_list)

# 動態重新命名
new_names = {}
for col in layer_df.columns:
    if col == layer_id_field: continue
    if col in csv_cols:
        new_names[col] = f"{col}_layer"
    else:
        new_names[col] = col
layer_df.rename(columns=new_names, inplace=True)

# 執行 Form 轉換
curr_form = new_names.get(form_field, form_field)
if curr_form in layer_df.columns:
    layer_df[curr_form] = layer_df[curr_form].astype(str).map(form_domain).fillna("Unknown")

# 🔥 執行 Fate 轉換 (從 target_fields 進來的 Fate)
curr_fate = new_names.get("Fate", "Fate")
if curr_fate in layer_df.columns:
    layer_df[curr_fate] = layer_df[curr_fate].astype(str).map(fate_domain).fillna("Unknown")

# ==========================================
# 3. 合併與計算
# ==========================================
csv_df[csv_id_field] = csv_df[csv_id_field].astype(str)
layer_df[layer_id_field] = layer_id_field_str = layer_df[layer_id_field].astype(str)

merged_df = pd.merge(csv_df, layer_df, left_on=csv_id_field, right_on=layer_id_field, how='outer', indicator=True)

# 邏輯反轉：both -> N (成功), right_only -> Y (遺失)
def judge_miss(x):
    if x == 'both': return 'N'
    if x == 'right_only': return 'Y'
    return 'Exception'

merged_df['grid_miss'] = merged_df['_merge'].apply(judge_miss)
merged_df[csv_id_field] = merged_df[csv_id_field].fillna(merged_df[layer_id_field])

final_df = merged_df[merged_df['grid_miss'] != 'Exception'].copy()

# 計算 CP_ratio
if 'Coral_count' in final_df.columns and 'Ncoral_count' in final_df.columns:
    denom = final_df['Ncoral_count'] + final_df['Coral_count']
    final_df['CP_ratio'] = np.where(denom > 0, final_df['Coral_count'] / denom, np.nan)

# 計算 Colony_Fate_GS
gry_col = new_names.get("Growth_Rate_Year", "Growth_Rate_Year")
if gry_col in final_df.columns:
    conditions = [(final_df[gry_col] == 0), (final_df[gry_col] > 1), (final_df[gry_col] > 0) & (final_df[gry_col] <= 1)]
    choices = ['D', 'G', 'S']
    final_df['Colony_Fate_GS'] = np.select(conditions, choices, default="None")

# 輸出前清理
final_df.drop(columns=['_merge', layer_id_field], inplace=True)
final_df.to_csv(output_csv, index=False, encoding='utf-8-sig')

# ==========================================
# 4. 純文字報告 (移除表情符號)
# ==========================================
success_count = len(final_df[final_df['grid_miss'] == 'N'])
miss_count = len(final_df[final_df['grid_miss'] == 'Y'])
total_layer = success_count + miss_count
success_ratio = (success_count / total_layer * 100) if total_layer > 0 else 0

area_col = new_names.get("Shape_Area", "Shape_Area")
# 報告用的 Fate 欄位
fate_report_col = curr_fate

large_miss_df = final_df[(final_df['grid_miss'] == 'Y') & (final_df[area_col] > THRESHOLD_5CM_AREA)]

print("-" * 85)
print("Data Integration Report")
print(f"Total layer samples: {total_layer}")
print(f"Successful matches (grid_miss=N): {success_count}")
print(f"Missing from grid (grid_miss=Y): {miss_count}")
print(f"Matching success rate: {success_ratio:.2f}%")
print("-" * 85)

if not large_miss_df.empty:
    print(f"Missing ID List (Area > 5cm threshold: {THRESHOLD_5CM_AREA:.6f} m2):")
    # 包含 ID, Form, Fate, Shape_Area
    print(large_miss_df[[csv_id_field, curr_form, fate_report_col, area_col]].to_string(index=False))
else:
    print("No large missing IDs detected.")
print("-" * 85)

# ==========================================
# 5. 族群結構圖 (log10 Size-Frequency)
# ==========================================
plot_df = final_df[final_df[area_col].notnull() & (final_df[area_col] > 0)].copy()
plot_df['log10_Area'] = np.log10(plot_df[area_col])

if not plot_df.empty:
    plt.figure(figsize=(11, 6))
    categories = sorted([f for f in plot_df[curr_form].unique() if f != "Unknown"])
    plot_data = [plot_df[plot_df[curr_form] == cat]['log10_Area'] for cat in categories]
    
    
    plt.hist(plot_data, bins=35, stacked=True, label=categories, edgecolor='white', alpha=0.85)

    plt.title('Coral Population Structure: Size-Frequency Distribution', fontsize=14)
    plt.xlabel('log10 Shape Area (m2)', fontsize=12)
    plt.ylabel('Frequency (Colony Count)', fontsize=12)
    plt.legend(title=curr_form, bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.grid(axis='y', linestyle=':', alpha=0.5)
    plt.tight_layout()
    plt.show()
# Out:
# -------------------------------------------------------------------------------------
# Data Integration Report
# Total layer samples: 1557
# Successful matches (grid_miss=N): 1086
# Missing from grid (grid_miss=Y): 471
# Matching success rate: 69.75%
# -------------------------------------------------------------------------------------
# Missing ID List (Area > 5cm threshold: 0.001963 m2):
# Colony_ID Form_layer Fate  Shape_Area_layer
#       590         fo   Fu          0.002344
#       633         en    G          0.002095
#       641         su    D          0.002025
#       651         br    G          0.001988
# -------------------------------------------------------------------------------------

# %%
## 多計算CP_ratio和簡化的GS命運在輸出
